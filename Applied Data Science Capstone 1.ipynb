# %% [markdown]
# # <h1 align = center><font size = 7>Applied Data Science Capstone </font><br><font size = 5>Part 1: Segmenting and Clustering in Toronto</font></h1>

# %% [markdown]
# For this part of the assignment it is required to scrap data from the Wikipedia page containing the postal codes of Canada. For this I will use `read_html` from the pandas library.

# %%
#Load Pandas
import pandas as pd

#Creation of the url containing the data:
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

#Reading the url and storing it on a list called data_raw:
data_raw = pd.read_html(url)
data_raw
# Out:
# [    Postal Code           Borough  \
#  0           M1A      Not assigned
#  1           M2A      Not assigned
#  2           M3A        North York
#  3           M4A        North York
#  4           M5A  Downtown Toronto
#  ..          ...               ...
#  175         M5Z      Not assigned
#  176         M6Z      Not assigned
#  177         M7Z      Not assigned
#  178         M8Z         Etobicoke
#  179         M9Z      Not assigned
#
#                                           Neighbourhood
#  0                                         Not assigned
#  1                                         Not assigned
#  2                                            Parkwoods
#  3                                     Victoria Village
#  4                            Regent Park, Harbourfront
#  ..                                                 ...
#  175                                       Not assigned
#  176                                       Not assigned
# ...

# %% [markdown]
# The result is a list that contains several dataframes. The index that seems to contain the dataframe needed to work is on the **index 0** of the list:

# %%
data_raw[0]
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# ...

# %% [markdown]
# Having figured out the data needed to start, I save it on a new dataframe to process it untill it's ready to be worked with:

# %%
df = data_raw[0]
df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# Now the dataframe is modified by filtering out all the Borough rows that are "Not assigned." Then the index is reset, dropping the old index and finally the first 12 rows are shown.

# %%
df = df[df["Borough"] != "Not assigned"].reset_index(drop = True)
df.head(12)
# Out:
#    Postal Code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# 4         Queen's Park, Ontario Provincial Government
# 5             Islington Avenue, Humber Valley Village
# 6                                      Malvern, Rouge
# 7                                           Don Mills
# ...

# %% [markdown]
# Altough the order and indexes differ from the sample rubric, I will not apply further proccessing to match the order of the example given. Since I do not know how the instructor came to that order, or I've been given further instructions on how to arrange the data.
#
# If the data was proccessed in the wrong way, it will show when further analysis is made.

# %%
#Print the shape of the dataframe:
df.shape
# Out:
# (103, 3)
